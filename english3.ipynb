# %%
import pandas as pd
import spacy
import pyinflect
import random

# %%
text2 =  '''
Little Red Cap

Jacob and Wilhelm Grimm

Once be know upon a time went there was a sweet little girl. Everyone who saw her liked her, but most of all her grandmother, who did not know what to give the child next. Once she gave her a little cap made of red velvet. Because it suited her so well, and she wanted to wear it all the time, she came to be known as Little Red Cap.
One day her mother said to her, "Come Little Red Cap. Here is a piece of cake and a bottle of wine. Take them to your grandmother. She is sick and weak, and they will do her well. Mind your manners and give her my greetings. Behave yourself on the way, and do not leave the path, or you might fall down and break the glass, and then there will be nothing for your sick grandmother."

Little Red Cap promised to obey her mother. The grandmother lived out in the woods, a half hour from the village. When Little Red Cap entered the woods a wolf came up to her. She did not know what a wicked animal he was, and was not an afraid of the him.
    '''

# %%
import nltk
from nltk.corpus import stopwords
tokens_sens = nltk.tokenize.sent_tokenize(text2, language='english')
#Создаем датафрейм
df_sentences = pd.DataFrame({'sentence': tokens_sens})
#st.write(df_sentences)

from nltk.tokenize import sent_tokenize
  
text = "Hello everyone. Welcome to GeeksforGeeks. You are studying NLP article"
sent_tokenize(text)

exercise_type = 'Выберите правильную форму глагола'
#exercise_type = 'Выбор правильного прилагательного'

exercise_type =  'Выберите правильный артикль'

options = []
task = ''
answer = ''


df = pd.DataFrame({'sentence':'', 'options': options, 'answer':answer, 'result':[], 'task':task})
nlp = spacy.load("en_core_web_sm") # изменение формы глагола с помощью pyinflect
for sentence in df_sentences.sentence:
    #print(len(sentence))
        #st.write(sentence)
    # options = ['a', 'the', 'an']
    lst=[]
    test_string = sentence.split(" ")
        
    for i in test_string:
        for j in ['a', 'the', 'an']:
            if i==j:
                lst.append(i)
                break  



    
    #if any(word in sentence for word in [' a ', ' the ', ' an ']):
    #    print(word)
    #for i in sentence:
    #    print(i)
    #matching = [x for ' a ' in sentence if x in sentence]

    for token in nlp(str(sentence)):
        
        # if token.text == 'the':
        #     print(sentence)
        if exercise_type == 'Выберите правильный артикль':
            answer = [i for i in [' a ', ' the ', ' an '] if i in sentence]
            answer = [x.strip(' ') for x in answer]
            options = ['a', 'the', 'an']        
        # if str(sentence) in  ['a', 'the', 'an'] and exercise_type == 'Выберите правильный артикль':
        #     
        #     answer = token
        #options = []
        if token.pos_=='VERB' and exercise_type == 'Выберите правильную форму глагола':
            answer = [token.text for token in nlp(str(sentence)) if token.pos_=='VERB']
            #options = [token._.inflect('VB'), token._.inflect('VBN'), token._.inflect('VBP'), token._.inflect('VBZ'), token._.inflect('VBG'), token._.inflect('VBD')]
            #s1, s2 =[token._.inflect('VB'), token._.inflect('VBN') for token in nlp(str(sentence)) if token.pos_=='VERB']
            # for i in answer:
            #     print(i)
            #     print(sent_tokenize(i)._.inflect('VB'))
            #print(list(set(['fsfd', 'dsfsdf' ,1 ,3 ,4, 1])))
            #print(set([token._.inflect('VB'), token._.inflect('VBN'), token._.inflect('VBP'), token._.inflect('VBZ'), token._.inflect('VBG'), token._.inflect('VBD')]))
            options.append(list(set([token._.inflect('VB'), token._.inflect('VBN'), token._.inflect('VBP'), token._.inflect('VBZ'), token._.inflect('VBG'), token._.inflect('VBD')])))
            task = token.pos_
            #print(options)
 #           {"be": {"VB": ["be"], "VBP": ["am", "are"], "VBN": ["been"], "VBD": ["was", "were"], "VBG": ["being"], "VBZ": ["is"]}}
#{"beach": {"VBN": ["beached"], "VB": ["beach"], "VBG": ["beaching"], "NN": ["beach"], "VBP": ["beach"], "VBZ": ["beaches"], "VBD": ["beached"], "NNS": ["beaches"]}}
            
            
        elif token.pos_=='ADJ'and exercise_type == 'Выбор правильного прилагательного':
            options = [token, token._.inflect('JJS'), token._.inflect('JJR'), token._.inflect('JJ'), token._.inflect('RB'), token._.inflect('RBR'), token._.inflect('RBS')]
            answer = token
            task = token.pos_ 
        else: pass
# отобрать предложения, где есть глагол или прилагательное
# отфильтровать короткие            
    # print(str(token))
    
    # sentence = sentence.replace(str(token), '___')
    # print(sentence)            
    if len(nlp(str(sentence))) > 3:
        df.loc[len(df)]=[sentence, options, answer, [], task]  
        options=[]  
        
        #print(sentence)
    #df['sentence'] = df['sentence'].apply(lambda x: x.replace(str(answer), ' ___ '))

# %%
with open('Little_Red_Cap_ Jacob_and_Wilhelm_Grimm.txt') as f:
    lines = f.read()

lines = lines.replace('\n','')
# Out:
# 'Once upon a time there was a sweet little girl. Everyone who saw her liked her, but most of all her grandmother, who did not know what to give the child next. Once she gave her a little cap made of red velvet. Because it suited her so well, and she wanted to wear it all the time, she came to be known as Little Red Cap.One day her mother said to her, "Come Little Red Cap. Here is a piece of cake and a bottle of wine. Take them to your grandmother. She is sick and weak, and they will do her well. Mind your manners and give her my greetings. Behave yourself on the way, and do not leave the path, or you might fall down and break the glass, and then there will be nothing for your sick grandmother."Little Red Cap promised to obey her mother. The grandmother lived out in the woods, a half hour from the village. When Little Red Cap entered the woods a wolf came up to her. She did not know what a wicked animal he was, and was not afraid of him."Good day to you, Little Red Cap.""Thank you, wolf.""Where are you going so early, Little Red Cap?""To grandmother\'s.""And what are you carrying under your apron?""Grandmother is sick and weak, and I am taking her some cake and wine. We baked yesterday, and they should give her strength.""Little Red Cap, just where does your grandmother live?""Her house is a good quarter hour from here in the woods, under the three large oak trees. There\'s a hedge of hazel bushes there. You must know the place," said Little Red Cap.The wolf thought to himself, "Now there is a tasty bite for me. Just how are you going to catch her?" Then he said, "Listen, Little Red Cap, haven\'t you seen the beautiful flowers that are blossoming in the woods? Why don\'t you go and take a look? And I don\'t believe you can hear how beautifully the birds are singing. You are walking along as though you were on your way to school in the village. It is very beautiful in the woods."Little Red Cap opened her eyes and saw the sunlight breaking through the trees and how the ground was covered with beautiful flowers. She thought, "If a take a bouquet to grandmother, she will be very pleased. Anyway, it is still early, and I\'ll be home on time." And she ran off into the woods looking for flowers. Each time she picked one she thought that she could see an even more beautiful one a little way off, and she ran after it, going further and further into the woods. But the wolf ran straight to the grandmother\'s house and knocked on the door."Who\'s there?""Little Red Cap. I\'m bringing you some cake and wine. Open the door for me.""Just press the latch," called out the grandmother. "I\'m too weak to get up."The wolf pressed the latch, and the door opened. He stepped inside, went straight to the grandmother\'s bed, and ate her up. Then he took her clothes, put them on, and put her cap on his head. He got into her bed and pulled the curtains shut.Little Red Cap had run after flowers, and did not continue on her way to grandmother\'s until she had gathered all that she could carry. When she arrived, she found, to her surprise, that the door was open. She walked into the parlor, and everything looked so strange that she thought, "Oh, my God, why am I so afraid? I usually like it at grandmother\'s." Then she went to the bed and pulled back the curtains. Grandmother was lying there with her cap pulled down over her face and looking very strange."Oh, grandmother, what big ears you have!""All the better to hear you with.""Oh, grandmother, what big eyes you have!""All the better to see you with.""Oh, grandmother, what big hands you have!""All the better to grab you with!""Oh, grandmother, what a horribly big mouth you have!""All the better to eat you with!" And with that he jumped out of bed, jumped on top of poor Little Red Cap, and ate her up. As soon as the wolf had finished this tasty bite, he climbed back into bed, fell asleep, and began to snore very loudly.A huntsman was just passing by. He thought it strange that the old woman was snoring so  ...

# %%
articles = []
#
articles
# Out:
# [[' a ', ' the ', ' an ']]

# %%
df
# Out:
#                                              sentence  \
# 0   \nLittle Red Cap\n\nJacob and Wilhelm Grimm\n\...
# 1   Everyone who saw her liked her, but most of al...
# 2   Once she gave her a little cap made of red vel...
# 3   Because it suited her so well, and she wanted ...
# 4   One day her mother said to her, "Come Little R...
# 5       Here is a piece of cake and a bottle of wine.
# 6                      Take them to your grandmother.
# 7    She is sick and weak, and they will do her well.
# 8        Mind your manners and give her my greetings.
# 9   Behave yourself on the way, and do not leave t...
# 10        Little Red Cap promised to obey her mother.
# 11  The grandmother lived out in the woods, a half...
# 12  When Little Red Cap entered the woods a wolf c...
# 13  She did not know what a wicked animal he was, ...
#
#                                               options  \
# 0   [[gone, goes, go, going, went], [been, being, ...
# 1   [[sees, see, seeing, seen, saw], [like, likes,...
# 2   [[give, gave, gives, given, giving], [makes, m...
# 3   [[suiting, suits, suited, suit], [wanted, want...
# 4   [[saying, said, say, says], [Come, Came, Comes...
# 5                                                  []
# 6                [[Taken, Taking, Takes, Took, Take]]
# 7                      [[does, did, do, done, doing]]
# 8   [[Minded, Mind, Minds, Minding], [give, gave, ...
# 9   [[Behaved, Behaving, Behaves, Behave], [left, ...
# 10  [[promised, promises, promise, promising], [ob...
# 11                     [[living, live, lived, lives]]
# 12  [[entered, enters, entering, enter], [came, co...
# 13              [[knowing, known, know, knows, knew]]
#
#                                  answer result  task
# 0                           [went, was]     []  VERB
# 1              [saw, liked, know, give]     []  VERB
# 2                          [gave, made]     []  VERB
# 3   [suited, wanted, wear, came, known]     []  VERB
# 4                          [said, Come]     []  VERB
# 5                          [said, Come]     []  VERB
# 6                                [Take]     []  VERB
# 7                                  [do]     []  VERB
# 8                          [Mind, give]     []  VERB
# 9          [Behave, leave, fall, break]     []  VERB
# 10                     [promised, obey]     []  VERB
# 11                              [lived]     []  VERB
# 12                      [entered, came]     []  VERB
# 13                               [know]     []  VERB

# %%
#df['sentence'] = df.sentence.apply(lambda x: 'asd')
df["sentence_hidden"] = df["sentence"]
for index, row in df.iterrows(): 
    for i in row.answer:
        df["sentence_hidden"][index] = df["sentence_hidden"][index].replace(i, ' ___ ')
        #print(row["sentence_hidden"][1])

#df["sentence_hidden"]= df.apply(lambda x: x['sentence'].replace(str(x['answer']), ' ___ '), axis=1)
#df["sentence_hidden"]= df.apply(lambda x: x['sentence'].replace(str([i.replace, ' ___ ' for i in x.answer]), ' ___ '), axis=1)
#df["sentence_hidden"]= df.apply(lambda x: [ for i in x.answer]  x['sentence'].replace([]' ___ '), axis=1)
#str(replace_words(['sge', 'sds'], list(df['sentence_hidden'][2]))

# %%
df.head(20)
# Out:
#                                              sentence  \
# 0   \nLittle Red Cap\n\nJacob and Wilhelm Grimm\n\...
# 1   Everyone who saw her liked her, but most of al...
# 2   Once she gave her a little cap made of red vel...
# 3   Because it suited her so well, and she wanted ...
# 4   One day her mother said to her, "Come Little R...
# 5       Here is a piece of cake and a bottle of wine.
# 6                      Take them to your grandmother.
# 7    She is sick and weak, and they will do her well.
# 8        Mind your manners and give her my greetings.
# 9   Behave yourself on the way, and do not leave t...
# 10        Little Red Cap promised to obey her mother.
# 11  The grandmother lived out in the woods, a half...
# 12  When Little Red Cap entered the woods a wolf c...
# 13  She did not know what a wicked animal he was, ...
#
#                                               options  \
# 0             [[know, known], [go, gone], [be, been]]
# 1   [[see, seen], [like, liked], [know, known], [g...
# 2                       [[give, given], [make, made]]
# 3   [[suit, suited], [want, wanted], [wear, worn],...
# 4                         [[say, said], [Come, Come]]
# 5                                                  []
# 6                                     [[Take, Taken]]
# 7                                        [[do, done]]
# 8                     [[Mind, Minded], [give, given]]
# 9   [[Behave, Behaved], [leave, left], [fall, fall...
# 10              [[promise, promised], [obey, obeyed]]
# 11                                    [[live, lived]]
# 12                   [[enter, entered], [come, come]]
# 13                                    [[know, known]]
#
#                                  answer result  task  \
# 0                     [know, went, was]     []  VERB
# 1              [saw, liked, know, give]     []  VERB
# 2                          [gave, made]     []  VERB
# 3   [suited, wanted, wear, came, known]     []  VERB
# 4                          [said, Come]     []  VERB
# 5                          [said, Come]     []  VERB
# 6                                [Take]     []  VERB
# 7                                  [do]     []  VERB
# 8                          [Mind, give]     []  VERB
# 9          [Behave, leave, fall, break]     []  VERB
# 10                     [promised, obey]     []  VERB
# 11                              [lived]     []  VERB
# 12                      [entered, came]     []  VERB
# 13                               [know]     []  VERB
#
#                                       sentence_hidden
# 0   \nLittle Red Cap\n\nJacob and Wilhelm Grimm\n\...
# 1   Everyone who saw her liked her, but most of al...
# 2   Once she gave her a little cap  ___  of red ve...
# 3   Because it suited her so well, and she wanted ...
# 4   One day her mother said to her, " ___  Little ...
# 5       Here is a piece of cake and a bottle of wine.
# 6                      ___  them to your grandmother.
# 7   She is sick and weak, and they will  ___  her ...
# 8       Mind your manners and  ___  her my greetings.
# 9   Behave yourself on the way, and do not leave t...
# 10       Little Red Cap promised to  ___  her mother.
# 11  The grandmother  ___  out in the woods, a half...
# 12  When Little Red Cap entered the woods a wolf  ...
# 13  She did not  ___  what a wicked animal he was,...

# %%
x = df["sentence_hidden"][1].split(" ___ ")
x
df['origin_sentences'].astype('unicode').values
# Out:
# ['Everyone who saw her liked her, but ',
#  ' of all her grandmother, who did not know what to give the child next.']

# %%
list = [1,2,3]
random.shuffle(list)
print(list)
# Out:
# [1, 3, 2]

# %%
for index, row in df.iterrows():
    #st.write(row['sentence'], row['answer'])
        
    print('Предложение:', str(row['sentence']))
    
    option = []
    for i in range(len(row['options'])):
        
        option.append(row['options'][i])

    df['result'][index] =  'ssss'

    if df['result'][index] == '–––':
        pass
            
    elif df['result'][index] == str(df['answer'][index]):
        print('Это правльный ответ')
            
    else:
        print('Попробуйте еще раз')
    

display(df)
# Out:
# Предложение:
# Little Red Cap
#
# Jacob and Wilhelm Grimm
#
# Once upon a time there was a sweet little girl.
# Попробуйте еще раз
# Предложение: Everyone who saw her liked her, but most of all her grandmother, who did not know what to give the child next.
# Попробуйте еще раз
# Предложение: Once she gave her a little cap made of red velvet.
# Попробуйте еще раз
# Предложение: Because it suited her so well, and she wanted to wear it all the time, she came to be known as Little Red Cap.
# Попробуйте еще раз
# Предложение: One day her mother said to her, "Come Little Red Cap.
# Попробуйте еще раз
# Предложение: Here is a piece of cake and a bottle of wine.
# Попробуйте еще раз
# Предложение: Take them to your grandmother.
# Попробуйте еще раз
# Предложение: She is sick and weak, and they will do her well.
# Попробуйте еще раз
# Предложение: Mind your manners and give her my greetings.
# Попробуйте еще раз
# Предложение: Behave yourself on the way, and do not leave the path, or you might fall down and break the glass, and then there will be nothing for your sick grandmother."
# Попробуйте еще раз
# Предложение: Little Red Cap promised to obey her mother.
# Попробуйте еще раз
# Предложение: The grandmother lived out in the woods, a half hour from the village.
# Попробуйте еще раз
# Предложение: When Little Red Cap entered the woods a wolf came up to her.
# Попробуйте еще раз
# Предложение: She did not know what a wicked animal he was, and was not afraid of him.
# Попробуйте еще раз
# Предложение: "Good day to you, Little Red Cap."
# Попробуйте еще раз
# Предложение: "Thank you, wolf."
# Попробуйте еще раз
# Предложение: "Where are you going so early, Little Red Cap?"
# Попробуйте еще раз
# Предложение: "To grandmother's."
# Попробуйте еще раз
# Предложение: "And what are you carrying under your apron?"
# Попробуйте еще раз
# Предложение: "Grandmother is sick and weak, and I am taking her some cake and wine.
# Попробуйте еще раз
# Предложение: We baked yesterday, and they should give her strength."
# Попробуйте еще раз
# Предложение: "Little Red Cap, just where does your grandmother live?"
# Попробуйте еще раз
# Предложение: "Her house is a good quarter hour from here in the woods, under the three large oak trees.
# Попробуйте еще раз
# Предложение: There's a hedge of hazel bushes there.
# Попробуйте еще раз
# Предложение: You must know the place," said Little Red Cap.
# Попробуйте еще раз
# Предложение: The wolf thought to himself, "Now there is a tasty bite for me.
# Попробуйте еще раз
# Предложение: Just how are you going to catch her?"
# Попробуйте еще раз
# Предложение: Then he said, "Listen, Little Red Cap, haven't you seen the beautiful flowers that are blossoming in the woods?
# Попробуйте еще раз
# Предложение: Why don't you go and take a look?
# Попробуйте еще раз
# Предложение: And I don't believe you can hear how beautifully the birds are singing.
# Попробуйте еще раз
# Предложение: You are walking along as though you were on your way to school in the village.
# Попробуйте еще раз
# Предложение: It is very beautiful in the woods."
# Попробуйте еще раз
# Предложение: Little Red Cap opened her eyes and saw the sunlight breaking through the trees and how the ground was covered with beautiful flowers.
# Попробуйте еще раз
# Предложение: She thought, "If a take a bouquet to grandmother, she will be very pleased.
# Попробуйте еще раз
# Предложение: Anyway, it is still early, and I'll be home on time."
# Попробуйте еще раз
# Предложение: And she ran off into the woods looking for flowers.
# Попробуйте еще раз
# Предложение: Each time she picked one she thought that she could see an even more beautiful one a little way off, and she ran after it, going further and further into the woods.
# Попробуйте еще раз
# Предложение: But the wolf ran straight to the grandmother's house and knocked on the door.
# Попробуйте еще раз
# Предложение: "Who's there?"
# Попробуйте еще раз
#                                              sentence  \
# 0   \nLittle Red Cap\n\nJacob and Wilhelm Grimm\n\...
# 1   Everyone who saw her liked her, but most of al...
# 2   Once she gave her a little cap made of red vel...
# 3   Because it suited her so well, and she wanted ...
# 4   One day her mother said to her, "Come Little R...
# 5       Here is a piece of cake and a bottle of wine.
# 6                      Take them to your grandmother.
# 7    She is sick and weak, and they will do her well.
# 8        Mind your manners and give her my greetings.
# 9   Behave yourself on the way, and do not leave t...
# 10        Little Red Cap promised to obey her mother.
# 11  The grandmother lived out in the woods, a half...
# 12  When Little Red Cap entered the woods a wolf c...
# 13  She did not know what a wicked animal he was, ...
# 14                 "Good day to you, Little Red Cap."
# 15                                 "Thank you, wolf."
# 16    "Where are you going so early, Little Red Cap?"
# 17                                "To grandmother's."
# 18      "And what are you carrying under your apron?"
# 19  "Grandmother is sick and weak, and I am taking...
# 20  We baked yesterday, and they should give her s...
# 21  "Little Red Cap, just where does your grandmot...
# 22  "Her house is a good quarter hour from here in...
# 23             There's a hedge of hazel bushes there.
# 24     You must know the place," said Little Red Cap.
# 25  The wolf thought to himself, "Now there is a t...
# 26              Just how are you going to catch her?"
# 27  Then he said, "Listen, Little Red Cap, haven't...
# 28                  Why don't you go and take a look?
# 29  And I don't believe you can hear how beautiful...
# 30  You are walking along as though you were on yo...
# 31                It is very beautiful in the woods."
# 32  Little Red Cap opened her eyes and saw the sun...
# 33  She thought, "If a take a bouquet to grandmoth...
# 34  Anyway, it is still early, and I'll be home on...
# 35  And she ran off into the woods looking for flo...
# 36  Each time she picked one she thought that she ...
# 37  But the wolf ran straight to the grandmother's...
# 38                                     "Who's there?"
#
#                                            word_forms     answer result task
# 0   [little, littlest, littler, little, little, li...     little   ssss  ADJ
# 1          [most, None, None, None, None, None, None]       most   ssss  ADJ
# 2   [red, reddest, redder, red, red, redder, reddest]        red   ssss  ADJ
# 3   [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 4   [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 5   [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 6   [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 7   [weak, weakest, weaker, weak, weak, weaker, we...       weak   ssss  ADJ
# 8   [weak, weakest, weaker, weak, weak, weaker, we...       weak   ssss  ADJ
# 9   [sick, sickest, sicker, sick, sick, sicker, si...       sick   ssss  ADJ
# 10  [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 11  [half, halfest, halfer, half, half, halfer, ha...       half   ssss  ADJ
# 12  [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 13  [afraid, afraiddest, afraidder, afraid, afraid...     afraid   ssss  ADJ
# 14  [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 15  [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 16  [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 17  [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 18  [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 19  [weak, weakest, weaker, weak, weak, weaker, we...       weak   ssss  ADJ
# 20  [weak, weakest, weaker, weak, weak, weaker, we...       weak   ssss  ADJ
# 21  [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 22  [large, largest, larger, large, large, larger,...      large   ssss  ADJ
# 23  [hazel, hazelest, hazeler, hazel, hazel, hazel...      hazel   ssss  ADJ
# 24  [Little, Littlest, Littler, Little, Little, Li...     Little   ssss  ADJ
# 25  [tasty, tastiest, tastier, tasty, tasty, tasti...      tasty   ssss  ADJ
# 26  [tasty, tastiest, tastier, tasty, tasty, tasti...      tasty   ssss  ADJ
# 27  [beautiful, beautifulest, beautifuler, beautif...  beautiful   ssss  ADJ
# 28  [beautiful, beautifulest, beautifuler, beautif...  beautiful   ssss  ADJ
# 29  [beautiful, beautifulest, beautifuler, beautif...  beautiful   ssss  ADJ
# 30  [beautiful, beautifulest, beautifuler, beautif...  beautiful   ssss  ADJ
# 31  [beautiful, beautifulest, beautifuler, beautif...  beautiful   ssss  ADJ
# 32  [beautiful, beautifulest, beautifuler, beautif...  beautiful   ssss  ADJ
# 33      [pleased, None, None, None, None, None, None]    pleased   ssss  ADJ
# 34      [pleased, None, None, None, None, None, None]    pleased   ssss  ADJ
# 35      [pleased, None, None, None, None, None, None]    pleased   ssss  ADJ
# 36  [little, littlest, littler, little, little, li...     little   ssss  ADJ
# 37  [little, littlest, littler, little, little, li...     little   ssss  ADJ
# 38  [little, littlest, littler, little, little, li...     little   ssss  ADJ
